# %%
from flask import Flask, request, render_template
from werkzeug.utils import secure_filename
from fileinput import filename
import tensorflow as tf
from keras.models import load_model
import os
from PIL import Image
import numpy as np
import cv2

# %%
categories_labels = {'Fighting': 0, 'Shoplifting': 1, 'Burglary': 2, 'Arrest': 3, 'Shooting': 4, 'Robbery': 5, 'Stealing': 6}
labels_categories = {v: k for k, v in categories_labels.items()}  # reverse dictionary for label lookup

# %%
# Load the trained model
model1 = load_model('CNN_RNN.h5')

# %%
def predict_image(image):
    # Resize the image
    image = cv2.resize(image, (50, 50))

    # Reshape the image to 4D
    image_cnn = image.reshape((1,) + image.shape + (1,))
    image_rnn = image.reshape((1,) + (-1, 1))

    prediction = model.predict([image_cnn, image_rnn])
    label = np.argmax(prediction)

    return labels_categories[label]

# %%
def extract_and_predict(gif_path):

    gif = Image.open(gif_path)
    # Extract frames from the gif
    frames = []
    try:
        while True:
            gif.seek(gif.tell() + 1)
            frames.append(np.array(gif.convert('L')))  # Convert image to grayscale
    except EOFError:
        pass

    # Predict the category of each frame and save it in a new directory
    new_dir = 'predicted_images'
    os.makedirs(new_dir, exist_ok=True)
    last_category = None  # variable to keep track of the last predicted category
    for i, frame in enumerate(frames):
        category = predict_image(frame)
        if category != last_category:  # only print the category if it's different from the last one
            print('Frame', i, 'Category:', category)
        last_category = category  # update the last predicted category
        cv2.imwrite(os.path.join(new_dir, f'{category}_{i}.png'), frame)

# %%
gif_path = "Test Data/test3.jpg"
extract_and_predict(gif_path)

# %%
categories_labels = {'Fighting': 0, 'Shoplifting': 1, 'Burglary': 2, 'Arrest': 3, 'Shooting': 4, 'Robbery': 5, 'Stealing': 6}
labels_categories = {v: k for k, v in categories_labels.items()}  # reverse dictionary for label lookup

# Load the trained model
model = load_model('CNN_RNN.h5')

def predict_image(image):
    # Resize the image
    image = cv2.resize(image, (50, 50))

    # Reshape the image to 4D
    image_cnn = image.reshape((1,) + image.shape + (1,))
    image_rnn = image.reshape((1,) + (-1, 1))

    prediction = model.predict([image_cnn, image_rnn])
    label = np.argmax(prediction)

    return labels_categories[label]

def extract_and_predict(gif_path):

    gif = Image.open(gif_path)

    # Extract frames from the gif
    frames = []
    try:
        while True:
            gif.seek(gif.tell() + 1)
            frames.append(np.array(gif.convert('L')))  # Convert image to grayscale
    except EOFError:
        pass

    # Predict the category of each frame and save it in a new directory
    new_dir = 'predicted_images'
    os.makedirs(new_dir, exist_ok=True)
    last_category = None  # variable to keep track of the last predicted category
    for i, frame in enumerate(frames):
        category = predict_image(frame)
        if category != last_category:  # only print the category if it's different from the last one
            print('Frame', i, 'Category:', category)
        last_category = category  # update the last predicted category
        cv2.imwrite(os.path.join(new_dir, f'{category}_{i}.png'), frame)

# Test the function
# Enter your gif path
gif_path = "Test Data/test2.gif"
extract_and_predict(gif_path)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Frame 0 Category: Shoplifting
# 1/1 [==============================] - 0s 180ms/step
# Frame 1 Category: Arrest
# 1/1 [==============================] - 0s 167ms/step
# Frame 2 Category: Fighting
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 152ms/step
# Frame 4 Category: Shoplifting
# 1/1 [==============================] - 0s 185ms/step
# Frame 5 Category: Stealing
# 1/1 [==============================] - 0s 158ms/step
# Frame 6 Category: Fighting
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 163ms/step
# Frame 9 Category: Arrest
# 1/1 [==============================] - 0s 157ms/step
# Frame 10 Category: Shoplifting
# 1/1 [==============================] - 0s 162ms/step
# Frame 11 Category: Fighting
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 151ms/step
# Frame 13 Category: Arrest
# 1/1 [==============================] - 0s 155ms/step
# Frame 14 Category: Fighting
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 183ms/step
# Frame 23 Category: Stealing
# 1/1 [==============================] - 0s 199ms/step
# Frame 24 Category: Shoplifting
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 168ms/step
# Frame 26 Category: Arrest
# 1/1 [==============================] - 0s 177ms/step
# Frame 27 Category: Shoplifting
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 169ms/step
# Frame 32 Category: Robbery
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 178ms/step
# Frame 34 Category: Stealing
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 177ms/step
# Frame 36 Category: Shoplifting
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 178ms/step
# Frame 40 Category: Stealing
# 1/1 [==============================] - 0s 188ms/step
# Frame 41 Category: Shoplifting
# 1/1 [==============================] - 0s 179ms/step
# Frame 42 Category: Stealing
# 1/1 [==============================] - 0s 181ms/step
# Frame 43 Category: Shoplifting
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 181ms/step
